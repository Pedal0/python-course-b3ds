# %%
import pandas as pd
df = pd.read_csv('./data/vgsales.csv')
df.query('platform == "NES"')
# Out:
#         rank                                               name platform  \
# 1          2                                  Super Mario Bros.      NES
# 9         10                                          Duck Hunt      NES
# 22        23                                Super Mario Bros. 3      NES
# 96        97                                Super Mario Bros. 2      NES
# 127      128                                The Legend of Zelda      NES
# ...      ...                                                ...      ...
# 5862    5864                                        Famista '91      NES
# 6161    6163                                        Famista '92      NES
# 10309  10311                               Final Fantasy I & II      NES
# 11985  11987  Teenage Mutant Ninja Turtles: Tournament Fighters      NES
# 12636  12638                                 Adventures of Lolo      NES
#
#          year         genre                     publisher  na_sales  eu_sales  \
# ...

# %%
round(df["jp_sales"].sum(), 2)
# Out:
# np.float64(1291.02)

# %%
len(df.query("year >= 2008").index)
# Out:
# 8004

# %%
(df[df["platform"] == "Wii"].count()[2] / df["platform"].count()) * 100
# Out:
# C:\Users\palex\AppData\Local\Temp\ipykernel_1368\600599075.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (df[df["platform"] == "Wii"].count()[2] / df["platform"].count()) * 100
# np.float64(7.982889504759609)
